# %%
import data as data
import data_Golomer as dataG
import data_Lelan as dataL
import data_OG_but_reduced as dataOG
from glob import glob
import model as Model
import train as Train
import trainTuning as tT
import predict as Predict
import pathlib
import mask_to_submission as m2s
import pandas as pd
import numpy as np
import predict as Predict
import cv2

# %%
# data.augment_split() # Loads all the data, does the data augmentation and splits them into train and valid dataset

# %%
Train.main_train() # Constructs and trains a model (parameters stored in model.h5 on the previously augmented data
# Out:
# ...
# 80150528/80134624 [==============================] - 1s 0us/step
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Epoch 1/10
# 450/450 [==============================] - 2485s 5s/step - loss: 0.0058 - dice_coef: 0.3271 - recall: 0.7205 - precision: 0.5406 - val_loss: 0.0048 - val_dice_coef: 0.3173 - val_recall: 0.4805 - val_precision: 0.9250 - lr: 1.0000e-04
# Epoch 2/10
# 450/450 [==============================] - 1682s 4s/step - loss: 0.0037 - dice_coef: 0.3664 - recall: 0.7664 - precision: 0.8046 - val_loss: 0.0030 - val_dice_coef: 0.3533 - val_recall: 0.7056 - val_precision: 0.8690 - lr: 1.0000e-04
# Epoch 3/10
# ...

# %%
Predict.main_predict() # takes the previously built model and evaluates it on the test set
# Out:
# ...
# 100%|██████████| 50/50 [08:53<00:00, 10.66s/it]

# %%
m2s.main_mask_to_submission()
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 161195.39it/s]
# ...
